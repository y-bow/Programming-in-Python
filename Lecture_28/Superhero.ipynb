# %%
import pandas as pd

# %%
df = pd.read_csv("superhero_powers.csv")

# %%
df.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...

# %%
hero_powers = pd.read_csv("superhero_powers.csv")
hero_powers
# Out:
#           hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0            3-D Man     True                False               False
# 1             A-Bomb    False                 True               False
# 2         Abe Sapien     True                 True               False
# 3           Abin Sur    False                False                True
# 4        Abomination    False                 True               False
# ..               ...      ...                  ...                 ...
# 662  Yellowjacket II    False                False               False
# 663             Ymir    False                False               False
# 664             Yoda     True                False               False
# 665          Zatanna    False                False               False
# 666             Zoom    False                False               False
#
#      Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# ...

# %%
hero_dc = pd.read_excel("superhero_info.xlsx", sheet_name = "DC Comics")
hero_marvel = pd.read_excel("superhero_info.xlsx", sheet_name = "Marvel Comics")

# %%
hero_dc.to_csv("hero_dc.csv",index = False)

# %%
hero_dc.to_pickle("hero.dc.pkl")

# %%
hero_dc_pkl = pd.read_pickle("hero.dc.pkl")

# %%
hero_dc_csv = pd.read_csv("hero_dc.csv")

# %%
hero_dc_csv.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        215 non-null    str
#  1   Gender      215 non-null    str
#  2   Eye color   215 non-null    str
#  3   Race        215 non-null    str
#  4   Hair color  215 non-null    str
#  5   Height      215 non-null    int64
#  6   Publisher   215 non-null    str
#  7   Alignment   215 non-null    str
#  8   Weight      144 non-null    float64
# dtypes: float64(1), int64(1), str(7)
# memory usage: 15.2 KB

# %%
hero_dtype={'name':'string','Gender':'category','Eye color':'string','Race':'string','Hair color':'string','Publisher':'string','Alignment':'category'}

# %%
hero_dc_pkl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        215 non-null    str
#  1   Gender      215 non-null    str
#  2   Eye color   215 non-null    str
#  3   Race        215 non-null    str
#  4   Hair color  215 non-null    str
#  5   Height      215 non-null    int64
#  6   Publisher   215 non-null    str
#  7   Alignment   215 non-null    str
#  8   Weight      144 non-null    float64
# dtypes: float64(1), int64(1), str(7)
# memory usage: 15.2 KB
